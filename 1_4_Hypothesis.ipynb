# %% [markdown]
# <div  style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
#
# **Даниил, привет! Рад с тобой познакомиться :)**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если удобнее на «вы», просто напиши, и мы сменим стиль общения.
#
# Я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Просьба не менять их местами и не удалять, чтобы наша работа над проектом была максимально продуктивной. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# ✍ Так выделены самые важные замечания. Без их исправления проект не будет принят. Я оцениваю не только код, но и его интерпретацию, а также соответствие техническому заданию.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 📝 Так выделены небольшие замечания или рекомендации, которые стоит учесть. Это не критично, но поможет сделать работу лучше. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# **Важные дополнения:**
#
# * <u>Идеально, когда проект структурирован. Где названия разделов и подразделов будут записаны в ячейках [Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/?).</u>
#
#
# * <u>Проверь проект на работоспособность перед отправкой на проверку. Сделать это можно так: `Kernel -> Restart And Run All -> Restart And Run All Cells` предварительно сохранив проект нажав на дискету в левом верхнем углу. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. Помни, ревьюеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (Сode/Markdown).</u>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# # Статистический анализ данных

# %% [markdown]
# **Описание проекта**: В условиях растущей конкуренции на рынке микромобильности сервисы аренды самокатов стремятся оптимизировать свои бизнес-модели. GoFast, как один из ключевых игроков этого рынка, сталкивается с необходимостью повышения прибыльности при сохранении лояльности пользователей. Анализ поведения клиентов и эффективности тарифных планов позволит выявить точки роста и сформировать стратегически важные решения для бизнеса.
#
# **Данные**: Данные о пользователях аренды самокатов GoFast: уникальный номер, имя, возраст, город, тип подписки. Информация о поездках: уникальный номер пользователя, дистанция, длительность, дата. И информация о тарифном плане, представленного в компании
#
# **Цель исследования**: Провести исследовательский анализ данных и посчитать помесячную выручку для каждого из пользователей. Проверить несколько гипотез, важных для бизнеса: узнать о наиболее вовлеченной группе пользователей, узнать о чрезмерном износе самокатов, сравнить прибыльность от владельцев разных подписок. Сделать общий вывод и предложить план улучшения ситуации

# %% [markdown]
# **Ход исследования**:
#
# - Изучение данных
# - Предобработка
#   - Изучение пропусков
#   - Изучение типизации
#   - Изучение дубликатов
#   - Добавление вспомогательных столбцов - вычисление помесячной выручки
# - Проверка гипотез
#   - Гипотеза о времени поездок пользователей разных тарифов
#   - Гипотеза о дистанции поездок пользователей с подпиской
#   - Гипотеза о выручке от пользователей с разными тарифами
# - Общий вывод

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝  Хорошо структурированное вступление делает проект более профессиональным, понятным и ценным для читателя и заказчика.
#
# Вот краткий пример на основе проекта: Исследовательский анализ данных.
#
# ![%D0%92%D1%81%D1%82%D1%83%D0%BF%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5.jpg](attachment:%D0%92%D1%81%D1%82%D1%83%D0%BF%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5.jpg)
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Дописал немного
# </div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats as st
import matplotlib.pyplot as plt 
from matplotlib.patches import Patch
from matplotlib.ticker import MultipleLocator

plt.style.use('ggplot')

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Правильно, что весь импорт ты проводишь в первой ячейке работы. Так твой коллега, запускающий работу, будет в курсе используемых в ней библиотек и сможет при необходимости быстро настроить окружение.
# </div>

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %% [markdown]
# ### Загрузка данных

# %%
try:
    users = pd.read_csv('./Data/users_go.csv')
    rides = pd.read_csv('./Data/rides_go.csv')
    subscriptions = pd.read_csv('./Data/subscriptions_go.csv')
except:
    users = pd.read_csv('/datasets/users_go.csv')
    rides = pd.read_csv('/datasets/rides_go.csv')
    subscriptions = pd.read_csv('/datasets/subscriptions_go.csv')

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Здорово, что следишь за универсальностью загрузки данных и используешь `try-except` блок.
# </div>

# %% [markdown]
# ### Изучение данных

# %%
# from ydata_profiling import ProfileReport

# dict_of_df = {
#     'users': users,
#     'rides': rides, 
#     'subscriptions': subscriptions
# }

# for data in dict_of_df:
#     (
#         ProfileReport(dict_of_df[data], title="Profiling Report")
#         .to_file(f'{data}.html')
#     )

# %% [markdown]
# Для каждого датасета получим:
# * первые значения
# * общую информацию о данных
# * При необходимости:
#   * количества уникальных значений

# %% [markdown]
# #### Users

# %%
users.head()
# Out:
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 61.3+ KB

# %%
users.nunique()
# Out:
# user_id              1534
# name                  194
# age                    29
# city                    8
# subscription_type       2
# dtype: int64

# %% [markdown]
# > Обратим внимание на то, что уникальных id меньше, чем данных - где-то есть дубликаты

# %% [markdown]
# #### Rides

# %%
rides.head()
# Out:
#    user_id     distance   duration        date
# 0        1  4409.919140  25.599769  2021-01-01
# 1        1  2617.592153  15.816871  2021-01-18
# 2        1   754.159807   6.232113  2021-04-20
# 3        1  2694.783254  18.511000  2021-08-11
# 4        1  4028.687306  26.265803  2021-08-28

# %%
rides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 564.8+ KB

# %% [markdown]
# #### Subscriptions

# %%
subscriptions.head()
# Out:
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0              free             8                50                 0
# 1             ultra             6                 0               199

# %% [markdown]
# > Тут просто хранится информация о подписках

# %% [markdown]
# **Вывод**:
#
# Таким образом в данных не обнаружено пропусков, типизация верная. Проблема с наличием полных дубликатов в таблице `users` решим далее. Данных много, распределения посмотрим далее

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝 Здесь у нас заканчивается вводная часть ознакомления с данными. Основная информация получена. Было бы неплохо также привести небольшое заключение по объему данных и основных ошибках, которые уже были обнаружены на этой стадии (типы данных, пропуски, названия колонок и др).
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Готово
# </div>

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# ### Пропуски

# %% [markdown]
# Судя по общей информации, пропусков в данных нет. Проверим еще раз

# %%
display(users.isna().sum())
display(rides.isna().sum())
display(subscriptions.isna().sum())
# Out:
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# dtype: int64
# user_id     0
# distance    0
# duration    0
# date        0
# dtype: int64
# subscription_type    0
# minute_price         0
# start_ride_price     0
# subscription_fee     0
# dtype: int64

# %% [markdown]
# ### Типизация

# %% [markdown]
# В данных нет пропусков, типизация тоже верная, за исключением столбца `date` - приведем его к типу datetime

# %%
rides['date'].dtypes
# Out:
# dtype('O')

# %%
rides['date'] = pd.to_datetime(
    rides['date'],
    format='%Y-%m-%d'
)

# %%
rides['date'].dtypes
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 При чтении файла можно указать параметр `parse_dates: parse_dates=['date']`. Тогда пандас автоматически переведет список столбцов в даты. Пример можно посмотреть [здесь](https://newtechaudit.ru/gruzi-daty-krasivo/).
# </div>

# %% [markdown]
# ### Дубликаты

# %% [markdown]
# Проверим сначала точные дубликаты

# %%
users.duplicated().sum()
# Out:
# 31

# %%
rides.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Удаляем все точные дубликаты

# %%
users = users.drop_duplicates()

# %% [markdown]
# Проверим по `user_id`

# %%
users.user_id.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Добавление вспомогательных столбцов

# %%
rides['month'] = rides.date.dt.month

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично, мы провели первичный анализ и познакомились с данными. Приступим к исследовательскому анализу.
# </div>

# %% [markdown]
# **Вывод**:
#
# Данные без пропусков и с нормальной типизацией. Перевели только дату в прикладной формат `pandas.datetime`. Найденные 31 дубликат выбросили

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# К сожалению отсутствует промежуточный вывод о проделанной работе в разделе. Дополни, пожалуйста.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# ### Users

# %% [markdown]
# Посчитаем основные описательные статистики

# %%
users.describe()
# Out:
#            user_id          age
# count  1534.000000  1534.000000
# mean    767.500000    24.903520
# std     442.971971     4.572367
# min       1.000000    12.000000
# 25%     384.250000    22.000000
# 50%     767.500000    25.000000
# 75%    1150.750000    28.000000
# max    1534.000000    43.000000

# %% [markdown]
# Еще раз посмотрим на то, какие данные есть в таблице

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1534 entries, 0 to 1533
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1534 non-null   int64
#  1   name               1534 non-null   object
#  2   age                1534 non-null   int64
#  3   city               1534 non-null   object
#  4   subscription_type  1534 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 71.9+ KB

# %% [markdown]
# Посмотрим на то, какие города представлены в данных

# %%
users.city.value_counts()
# Out:
# Пятигорск         219
# Екатеринбург      204
# Ростов-на-Дону    198
# Краснодар         193
# Сочи              189
# Омск              183
# Тюмень            180
# Москва            168
# Name: city, dtype: int64

# %% [markdown]
# Построим распределения основных показателей

# %%
fig, axs = plt.subplots(2, 2, constrained_layout=True)
fig.set_size_inches(10, 10)

axs[0][0].set_title('Распределение пользователей по возрастам')
sns.histplot(users['age'], ax=axs[0][0])
axs[0][0].set_xlabel('Возраст')
axs[0][0].set_ylabel('Число записей')

axs[0][1].set_title('Распределение пользователей по городам')
ct = sns.countplot(data=users, x='city', ax=axs[0][1])
axs[0][1].set_xlabel('Город')
axs[0][1].set_ylabel('Число записей')
axs[0][1].tick_params(axis='x', rotation=45)
# for label in ct.containers:
#     axs[1][0].bar_label(label)


axs[1][0].set_title('Распределение пользователей по типу подписки')
type_counts = users.subscription_type.value_counts()
axs[1][0].pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', startangle=90)
# for label in gr.containers:
#     axs[1][0].bar_label(label)

fig.delaxes(axs[1, 1])

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# К сожалению здесь код упал с ошибкой. Поправь, пожалуйста и я буду ждать твой проект на повторное ревью.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Не могу не отметить отличную визуализацию. Здорово, что оформляешь графики правильно.
# </div>

# %% [markdown]
# > Похоже на то, что возраст имеет распределение Стьюдента с максимумом в 25. Распределение записей по городам имеет распределение близкое к равномерному - по крайней мере нет явного перевеса. Аналогичная ситуация с типом подписки.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Замечания:
#
#
# * Частота встречаемости городов: Очень не хватает цифр. Прошу тебя вывести таблицу с числовыми значениями частотности городов.
#
#
# * Соотношение пользователей с подпиской и без подписки: Здесь нас просят показать соотношение, а его принято показывать в долях. Также, здесь хорошо подойдет круговая диаграмма.
#
#
# * Прошу написать выводы по шагам 3.1 и 3.2.
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Тут хотел вывести значения на сами графики. Но в системе используется устаревшая версия python, и в matplotlib еще нет нужного атрибута 'bar_label'. Так что придется просто вывести таблицу
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
#
# </div>

# %% [markdown]
# Посмотрим как хорошо люди покупают подписки в разных городах

# %%
fig, ax = plt.subplots()

ax.set_title('Распределение пользователей по городам и типам подписки')
sns.countplot(data=users, x='city', hue='subscription_type')
ax.set_xlabel('Город')
ax.set_ylabel('Число записей')
ax.tick_params(axis='x', rotation=45)
plt.legend(loc='upper right');

# %% [markdown]
# > Получили, что в Москве и Омске количество платных и бесплатных подписок почти одинаковы

# %% [markdown]
# ### Rides

# %% [markdown]
# Выведем основные описательные статистики

# %%
rides.describe()
# Out:
#             user_id      distance      duration         month
# count  18068.000000  18068.000000  18068.000000  18068.000000
# mean     842.869936   3070.659976     17.805011      6.486772
# std      434.734317   1116.831209      6.091051      3.437410
# min        1.000000      0.855683      0.500000      1.000000
# 25%      487.000000   2543.226360     13.597563      4.000000
# 50%      889.000000   3133.609994     17.678395      6.000000
# 75%     1213.250000   3776.222735     21.724800      9.000000
# max     1534.000000   7211.007745     40.823963     12.000000

# %% [markdown]
# Построим распределения основных показателей

# %%
fig, axs = plt.subplots(1, 2, constrained_layout=True)
fig.set_size_inches(10, 6)

axs[0].set_title('Распределение поездок по дистанциям')
sns.histplot(rides['distance'], ax=axs[0])
axs[0].set_xlabel('Дисанция, м')
axs[0].set_ylabel('Число записей')

axs[1].set_title('Распределение поездок по длительностям')
sns.histplot(rides, x='duration', ax=axs[1])
axs[1].set_xlabel('Длительность, мин.')
axs[1].set_ylabel('Число записей');

# %% [markdown]
# Посмотрим что за два пика присутствуют на графике распределения дистанций

# %%
display(rides.distance.max())
display(rides[rides['distance'] < 1500].distance.max())
# Out:
# 7211.007744598519
# 1499.56583040855

# %% [markdown]
# > То есть у нас есть два типа поездок - дальние и близкие. Для каждого типа есть свои распределения, похожие на нормальные

# %% [markdown]
# Посмотрим на маленький пик в длительностях поездок

# %%
rides[rides['duration'] < 5].duration.mode()[0]
# Out:
# 0.5

# %% [markdown]
# Причин появления такого пика могут быть различны. Например, система может округлять очень короткие поездки до 30 секунд. Также это может быть какой-то пробный период, за который клиент проверяет самокат и может вернять его в случае наисправности. Также это могут быть тестовые проверки самокатов.
#
# Проверим на какие дистанции проезжает самокат за это время

# %%
(
    rides[rides['duration'] == 0.5]
    .distance
    .plot(
        title='Распределение дистанций коротких поездок',
        xlabel='Дистанция, м',
        ylabel='Число записей',
        kind='hist',
        bins=30
    )
);

# %% [markdown]
# Значения дистанций для этих коротких поездок разнообразны - так что это, вероятнее всего, какая-то ошибка в расчетах. Удалим эти данные из данных

# %%
# rides = rides[rides['duration'] != 0.5]

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# В случае с данными о пользователях, которые используют самокаты, если оплата за эти данные была получена, то они представляют собой реальные наблюдения, а не аномалии или выбросы. Удалять такие наблюдения может привести к потере важной информации и возможным искажениям результатов и выводов на основе анализа данных.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Последовав указанию, я не буду удалять эти данные. Однако не понимаю, как поездки, в которых пользователь проезжает несколько километров за 30 секунд, могут быть презентативными
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍 Короткие поездки с большим расстоянием могут казаться аномальными, но иногда они отражают реальные особенности работы устройства или сервиса. Например, если система считывает данные о поездке с ошибкой из-за технического сбоя, данные могут быть искажены, но всё равно представляют собой реальные наблюдения.
#
#
# **Возможный компромисс:** Если такие данные составляют небольшую долю, ты можешь создать отдельный набор данных только с этими поездками и при необходимости проанализировать их отдельно. Так ты сможешь сохранить их для полноты анализа, но при этом не включать их в общие расчёты. Это может быть полезно, если эти выбросы не соответствуют общей логике, но при этом представляют интерес для анализа поведения системы или пользователей.
#
#
#
# Когда удаление оправдано: Есть уверенность, что данные являются ошибкой (например, известны сбои в системе отслеживания).
#
#
#
# </div>

# %% [markdown]
# **Вывод**:
#
# Таблица с данными о пользователях имеют хорошие распределения, нет ярких выбросов или перекосов по каким-либо параметрам. В таблице с поездками можно наблюдать два пика разных размеров на дистанциях порядка 1.5 км и 7 км. Длительности поездок распределены равномерно, но присутствует некоторый пик на 30 секнудах.

# %% [markdown]
# ## Шаг 4. Объединение данных

# %% [markdown]
# Объединим 3 таблицы в одну. В качестве ключа возьмем `user_id`

# %%
subscriptions.columns
# Out:
# Index(['subscription_type', 'minute_price', 'start_ride_price',
#        'subscription_fee'],
#       dtype='object')

# %%
print(f'Размер исходной таблицы users: {users.shape}')
print(f'Размер исходной таблицы rides: {rides.shape}')
print(f'Размер исходной таблицы subscriptions: {subscriptions.shape}')

data = users.merge(
    rides, 
    on='user_id',
    how='left'
    )

data = data.merge(
    subscriptions,
    on='subscription_type',
    how='left'
)

print(f'Размер получившейся таблицы data: {data.shape}')
# Out:
# Размер исходной таблицы users: (1534, 5)
# Размер исходной таблицы rides: (18068, 5)
# Размер исходной таблицы subscriptions: (2, 4)
# Размер получившейся таблицы data: (18068, 12)

# %% [markdown]
# Количество объектов в получившейся таблице совпадает с этим количеством в таблице с поездками, то есть в полученной таблице ни одна поездка не потерялась. Количество столбцов совпадает с суммой столбцов (за вычетом двух объединяющих) в исходных таблицах.

# %%
data.head()
# Out:
#    user_id  name  age    city subscription_type     distance   duration  \
# 0        1  Кира   22  Тюмень             ultra  4409.919140  25.599769
# 1        1  Кира   22  Тюмень             ultra  2617.592153  15.816871
# 2        1  Кира   22  Тюмень             ultra   754.159807   6.232113
# 3        1  Кира   22  Тюмень             ultra  2694.783254  18.511000
# 4        1  Кира   22  Тюмень             ultra  4028.687306  26.265803
#
#         date  month  minute_price  start_ride_price  subscription_fee
# 0 2021-01-01      1             6                 0               199
# 1 2021-01-18      1             6                 0               199
# 2 2021-04-20      4             6                 0               199
# 3 2021-08-11      8             6                 0               199
# 4 2021-08-28      8             6                 0               199

# %% [markdown]
# Проверим не появились ли пропуски в таблице после объединения

# %%
data.isna().sum()
# Out:
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# distance             0
# duration             0
# date                 0
# month                0
# minute_price         0
# start_ride_price     0
# subscription_fee     0
# dtype: int64

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Объединение прошло корректно.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Замечания:
#
# * Для начала следует посмотреть исходную размерность датасетов
#
# * После объединения размерность таблицы, к которой присоединяем должна совпадать с исходной.
#
# * Отсутствует проверка на пропуски в объединенном датасете.
#
# Дополни, пожалуйста.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
#
# </div>

# %% [markdown]
# Разделим данные на пользователей с подпиской и без

# %%
data_ultra = data[data['subscription_type'] == 'ultra']
data_free = data[data['subscription_type'] == 'free']

# %% [markdown]
# Визуализируем распределения длительности поездок и их расстояний для этих подвыборок

# %%
fig, ax = plt.subplots(2, 2, constrained_layout=True)
fig.set_size_inches(12, 12)

ax[0][0].set_title('Free поездки по дальности и городам')
sns.histplot(data=data_free, x='distance', ax=ax[0][0],
              hue='city', multiple='stack', palette="brg", legend=True)
ax[0][0].set_xlabel('Дистанция, м')
ax[0][0].set_ylabel('Число записей')

ax[0][1].set_title('Ultra поездки по дальности и городам')
sns.histplot(data=data_ultra, x='distance', ax=ax[0][1],
              hue='city', multiple='stack', palette="brg", legend=True)
ax[0][1].set_xlabel('Дистанция, м')
ax[0][1].set_ylabel('Число записей')

ax[1][0].set_title('Free поездки по длительности и городам')
sns.histplot(data=data_free, x='duration', ax=ax[1][0],
              hue='city', multiple='stack', palette="brg", legend=True)
ax[1][0].set_xlabel('Длительность, мин.')
ax[1][0].set_ylabel('Число записей')

ax[1][1].set_title('Ultra поездки по длительности и городам')
sns.histplot(data=data_ultra, x='duration', ax=ax[1][1],
              hue='city', multiple='stack', palette="brg", legend=True)
ax[1][1].set_xlabel('Длительность, мин.')
ax[1][1].set_ylabel('Число записей')
# Out:
# Text(0, 0.5, 'Число записей')

# %% [markdown]
# > Можно увидеть, что наиболее часто близкие поездки совершаются в Ростова-на-Дону. Причем в общем количество коротких поездок пользователей без подписок почти в 4 раза больше коротких поездок пользователей с подпиской.
#
# > Также видим, что имеющийся пик на длительности 0.5 мин есть только в информации о пользователей без подписок

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Выводы верны, визуализация корректная. Здорово, что есть сравнения профилей пользователей двух категорий.
# </div>

# %% [markdown]
# ## Шаг 5. Подсчёт выручки

# %% [markdown]
# Создадим общую таблицу с суммарным расстоянием, суммарным временем поездок и числом таких поездок для каждого пользователя. Добавим столбец с округленными в большую сторону длительностями. Также сохраним информацию о тарифном плане пользователя

# %%
aggregated_data = (
    data
    .assign(rounded_duration=lambda x: np.ceil(x['duration']))
    .groupby(['user_id', 'month'])
    .agg(
        month_distance=('distance', 'sum'),
        month_duration=('duration', 'sum'),
        month_rounded_duration=('rounded_duration', 'sum'),
        number_of_month_trips=('duration', 'count'),
        minute_price=('minute_price', 'first'),
        start_ride_price=('start_ride_price', 'first'),
        subscription_fee=('subscription_fee', 'first'),
        subscription_type=('subscription_type', 'first')
        )
    .reset_index()
)

# %%
aggregated_data.head()
# Out:
#    user_id  month  month_distance  month_duration  month_rounded_duration  \
# 0        1      1     7027.511294       41.416640                    42.0
# 1        1      4      754.159807        6.232113                     7.0
# 2        1      8     6723.470560       44.776802                    46.0
# 3        1     10     5809.911100       31.578017                    32.0
# 4        1     11     7003.499363       53.397424                    56.0
#
#    number_of_month_trips  minute_price  start_ride_price  subscription_fee  \
# 0                      2             6                 0               199
# 1                      1             6                 0               199
# 2                      2             6                 0               199
# 3                      2             6                 0               199
# 4                      3             6                 0               199
#
#   subscription_type
# 0             ultra
# 1             ultra
# ...

# %% [markdown]
# Вычислим выручку. И для наглядности удалим ненужные столбцы

# %%
aggregated_data['revenue'] = (
    aggregated_data['start_ride_price']
    * aggregated_data['number_of_month_trips']
    + aggregated_data['minute_price']
    * aggregated_data['month_rounded_duration']
    + aggregated_data['subscription_fee']
)

# %%
aggregated_data.head()
# Out:
#    user_id  month  month_distance  month_duration  month_rounded_duration  \
# 0        1      1     7027.511294       41.416640                    42.0
# 1        1      4      754.159807        6.232113                     7.0
# 2        1      8     6723.470560       44.776802                    46.0
# 3        1     10     5809.911100       31.578017                    32.0
# 4        1     11     7003.499363       53.397424                    56.0
#
#    number_of_month_trips  minute_price  start_ride_price  subscription_fee  \
# 0                      2             6                 0               199
# 1                      1             6                 0               199
# 2                      2             6                 0               199
# 3                      2             6                 0               199
# 4                      3             6                 0               199
#
#   subscription_type  revenue
# 0             ultra    451.0
# ...

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Проделана большая работа, но есть замечания:
#
#
# * Округление duration произведено уже после агрегации: Ты сначала посчитал суммарное month_duration, а потом применил np.ceil() к итоговому значению. Это некорректно — округлять нужно каждую отдельную поездку, а не итоговую сумму. В результате у тебя получается заниженная выручка, особенно если в месяц много коротких поездок.
#
#
# * Не учтена подписка (subscription_fee): По заданию ежемесячная плата входит в общую выручку, если пользователь на Ultra. У тебя она не включена — в результате ты занижаешь итоговую выручку для подписчиков. Это критично, потому что влияет на сравнение revenue по типам подписки в следующих гипотезах.
#
#
# * Удаление промежуточных колонок до завершения расчётов: Ты удаляешь столбцы сразу после расчёта revenue. Это затрудняет отладку, проверку корректности и дальнейший анализ. Лучше держать полные данные до самого конца, чтобы не терять прозрачность логики.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
#
# </div>

# %% [markdown]
# Посмотрим на распределение выручек в обеих группах

# %%
fig, axs = plt.subplots(1, 2, constrained_layout=True)
fig.set_size_inches(10, 6)

axs[0].set_title('Распределение выручки без подписки')
sns.histplot(
    aggregated_data[aggregated_data['subscription_type'] == 'free']['revenue']
    , ax=axs[0]
)
axs[0].set_xlabel('Выручка')
axs[0].set_ylabel('Число записей')

axs[1].set_title('Распределение выручки с подпиской')
sns.histplot(
    aggregated_data[aggregated_data['subscription_type'] == 'ultra']['revenue']
    , ax=axs[1]
)
axs[1].set_xlabel('Выручка')
axs[1].set_ylabel('Число записей');

# %% [markdown]
# Выручка распределена без особой закономерности - можем видеть только основные пики. Видим, что пик пользователей без подписки левее того же для подписки

# %% [markdown]
# ## Шаг 6. Проверка гипотез

# %% [markdown]
# ### Гипотеза о временах поездки для владельцев подписки и людей без нее
#
#  Важно понять, тратят ли пользователи с подпиской больше времени на поездки. Если да, то пользователи с подпиской могут быть «выгоднее» для компании.
#
# Сформулируем гипотезы
#
# $H_0$: Обе группы тратят одинаковое время
#
# $H_1$: Люди с подпиской тратят больше времени

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Гипотезы сформулированы верно.
# </div>

# %% [markdown]
# Проверим нормально ли распределены длительности поездок в обеих группах. Проведем [тест Шапиро — Уилка](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.shapiro.html).

# %%
shapiro_ultra_duration = st.shapiro(data_ultra.duration)
shapiro_free_duration = st.shapiro(data_free.duration)

print(f'''Тест Шапиро-Уилка для пользователей с подпиской:\
 p-value = {shapiro_ultra_duration.pvalue}''')
print(f'Тест Шапиро-Уилка для пользователей без подписки:\
 p-value = {shapiro_free_duration.pvalue}');
# Out:
# Тест Шапиро-Уилка для пользователей с подпиской: p-value = 3.0510050003555167e-21
# Тест Шапиро-Уилка для пользователей без подписки: p-value = 2.665247016142569e-11
# /opt/conda/lib/python3.9/site-packages/scipy/stats/_morestats.py:1800: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# Мы получили очень низкое значние `p-value`, то есть гипотезу о нормальности распределения можем отвергнуть. Таким образом, использовать T-test не очень верно. Тем не менее попробуем провести его + проведем непараметрический тест Манна-Уитни, который более предпочтительный в нашей задаче.

# %% [markdown]
# **T-test**

# %%
t_test_duration = st.ttest_ind(
    data_ultra.duration, 
    data_free.duration,
    alternative='greater'
    )

alpha = 0.05

print(f'Независимый t-test: p-value = {t_test_duration.pvalue}')

if t_test_duration.pvalue < alpha:
    print('Гипотеза отвергается')
else:
    print('Гипотеза не отвергается')
# Out:
# Независимый t-test: p-value = 1.2804098316645618e-34
# Гипотеза отвергается

# %% [markdown]
# > Заметим, что если бы данные все-таки были нормально распределены, то стоило бы проверить равенство дисперсия, то есть провести дополнительно провести [тест Левена](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.levene.html). И по его результатам указали бы значение переменной `equal_var`

# %% [markdown]
# **Тест Манна-Уитни**

# %%
u_test_duration = st.mannwhitneyu(
    data_ultra.duration,
    data_free.duration,
    alternative='greater'
)

alpha = 0.05

print(f'U-test: p-value = {u_test_duration.pvalue}')

if u_test_duration.pvalue < alpha:
    print('Гипотеза отвергается')
else:
    print('Гипотеза не отвергается')
# Out:
# U-test: p-value = 3.0317220611813157e-28
# Гипотеза отвергается

# %% [markdown]
# **Сравнение средних**

# %%
print(f'''Средняя и медианная длительность для пользователей с подпиской:
    mean: {data_ultra.duration.mean()}
    median: {data_ultra.duration.median()}''')

print(f'''\nСредняя и медианная длительность для пользователей без подписки:
    mean: {data_free.duration.mean()}
    median: {data_free.duration.median()}''')
# Out:
# Средняя и медианная длительность для пользователей с подпиской:
#     mean: 18.54198516280583
#     median: 18.17815320055055
#
# Средняя и медианная длительность для пользователей без подписки:
#     mean: 17.39090929866399
#     median: 17.326890226082043

# %% [markdown]
# **Вывод:**
#
# Оба теста отвергают гипотезу о равенстве средних двух выборок, при этом принимается гипотеза о том, что пользователи с подпиской тратят больше времени на поездки. В целом, мы можем наблюдать это, сравнивая срдение и медианные значения двух выборок

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Верно
# </div>

# %% [markdown]
# ### Гипотеза о дистанции поездки пользователей с подпиской
#
# Расстояние одной поездки в 3130 метров — оптимальное с точки зрения износа самоката. Стоит проверить гипотезу о том, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров.
#
# Сформулируем гипотезы
#
#  $H_0$: Среднее расстояние пользователей с подпиской не больше 3130 м
#
#  $H_1$: Подписчики в среднем проезжают расстояние больше 3130 м

# %% [markdown]
# Также проверим нормально ли распределены дистанции поездок

# %%
shapiro_ultra_distance = st.shapiro(data_ultra.distance)

print(f'''Тест Шапиро-Уилка для пользователей с подпиской:\
 p-value = {shapiro_ultra_distance.pvalue}''');
# Out:
# Тест Шапиро-Уилка для пользователей с подпиской: p-value = 0.0
# /opt/conda/lib/python3.9/site-packages/scipy/stats/_morestats.py:1800: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# Мы получили очень низкое значние `p-value`, то есть гипотезу о нормальности распределения можем отвергнуть. В целом, можно было понять это и по графику распределения, но теперь мы в этом точно уверены.

# %% [markdown]
# Проверим симметричность данных

# %%
data_ultra.distance.skew()
# Out:
# -0.8328163548453281

# %% [markdown]
# Здесь стоит, как и для прошлой гипотезы, использовать непараметрический тест. Однако, судя по распределению, дистанции распределены не только не нормально, но и ассиметрично (судя по показателю перекоса $\in[-1, -0.5]$, мы имеем умеренно отрицательный (левый) перекос). Так что и непарамтерический тест подобрать трудно. Воспользуемся [непараметрическим тестом Уилкоксона](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.wilcoxon.html)

# %%
wilcoxon_test_ultra_duration = st.wilcoxon(
    data_ultra.distance - 3130,
    alternative='greater'  
)

print(f'Тест Уилкоксона:\
 p-value = {wilcoxon_test_ultra_duration.pvalue}')

alpha = 0.05

if wilcoxon_test_ultra_duration.pvalue < alpha:
    print('Гипотеза отвергается')
else:
    print('Гипотеза не отвергается')
# Out:
# Тест Уилкоксона: p-value = 0.0001690509558810868
# Гипотеза отвергается

# %% [markdown]
# Попробуем и t-test

# %%
ttest_ultra_duration = st.ttest_1samp(
    data_ultra.distance,
    3130,
    alternative='greater'
)

print(f'T-test:\
 p-value = {ttest_ultra_duration.pvalue}')

alpha = 0.05

if ttest_ultra_duration.pvalue < alpha:
    print('Гипотеза отвергается')
else:
    print('Гипотеза не отвергается')
# Out:
# T-test: p-value = 0.9195368847849785
# Гипотеза не отвергается

# %% [markdown]
# **Проверка среднего**

# %%
print(f'''Средняя и медианная дальность для пользователей с подпиской:
    mean: {data_ultra.distance.mean()}
    median: {data_ultra.distance.median()}''')
# Out:
# Средняя и медианная дальность для пользователей с подпиской:
#     mean: 3115.4453880370247
#     median: 3148.6372291760854

# %% [markdown]
# **Вывод**:
#
# Таким образом, несмотря на то, что среднее меньше 3130 м, статистически, согласно t-тесту, мы не можем отвергать гипотезу о том, что средняя дистанция не больше порога. Однако тест Уилкоксона, проверяющий распределены ли значения симметрично около 0, отвергает эту гипотезу, в пользу того, что среднее значение все-таки больше.
#
# Так как данные не распределены по нормальному закону и имеют сильный перекос, в этой задаче стоит все-таки отвергнуть гипотезу о том, что среднее время подписчиков не больше оптимального.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Поскольку оптимальное расстояние по износу составляет 3130 м, значит большее расстояние приводит к повышенному износу самоката. Следовательно, имеет смысл сформулировать альтернативную гипотезу "Подписчики в среднем проезжают расстояние больше оптимального" и соответственно в статистическом тесте использовать параметр `alternative = 'greater'`
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
#
# </div>

# %% [markdown]
# ### Гипотеза о помесячной выручке для пользователей с подпиской и без
#
# Стоит проверить гипотезу о том, будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки.
#
# Сформулируем гипотезы
#
#  $H_0$: Средняя помесячная выручка от двух групп равна
#
#  $H_1$: Средняя выручка от подписчиков выше

# %%
data_revenue_ultra = (
    aggregated_data
    .loc[aggregated_data['subscription_type'] == 'ultra', 'revenue']
    )

data_revenue_free = (
    aggregated_data
    .loc[aggregated_data['subscription_type'] == 'free', 'revenue']
    )

# %% [markdown]
# Проверим как распределены данные

# %%
shapiro_ultra_revenue = st.shapiro(data_revenue_ultra)
shapiro_free_revenue = st.shapiro(data_revenue_free)

print(f'''Тест Шапиро-Уилка для пользователей с подпиской:\
 p-value = {shapiro_ultra_revenue.pvalue}''')
print(f'Тест Шапиро-Уилка для пользователей без подписки:\
 p-value = {shapiro_free_revenue.pvalue}');
# Out:
# Тест Шапиро-Уилка для пользователей с подпиской: p-value = 0.0
# Тест Шапиро-Уилка для пользователей без подписки: p-value = 0.0
# /opt/conda/lib/python3.9/site-packages/scipy/stats/_morestats.py:1800: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# Проверим асимметричность данных

# %%
print(f'Показатель перекоса выручки от пользователей с подпиской:\
 {data_revenue_ultra.skew()}')

print(f'Показатель перекоса выручки от пользователей без подписки:\
 {data_revenue_free.skew()}')
# Out:
# Показатель перекоса выручки от пользователей с подпиской: 1.548002095914749
# Показатель перекоса выручки от пользователей без подписки: 1.3362457533067031

# %% [markdown]
# Таким образом, данные распределены не нормально. При этом есть сильный положительный (правый) перекос. Будем использовать тест Манна-Уитни

# %% [markdown]
# **Тест Манна-Уитни**

# %%
u_test_revenue = st.mannwhitneyu(
    data_revenue_ultra,
    data_revenue_free,
    alternative='greater'
)

alpha = 0.05

print(f'U-test: p-value = {u_test_revenue.pvalue}')

if u_test_revenue.pvalue < alpha:
    print('Гипотеза отвергается')
else:
    print('Гипотеза не отвергается')
# Out:
# U-test: p-value = 1.3577968590692359e-132
# Гипотеза отвергается

# %% [markdown]
# Также проведем и t-test

# %%
t_test_revenue = st.ttest_ind(
    data_revenue_ultra,
    data_revenue_free,
    alternative='greater'
    )

alpha = 0.05

print(f'Независимый t-test: p-value = {t_test_revenue.pvalue}')

if t_test_revenue.pvalue < alpha:
    print('Гипотеза отвергается')
else:
    print('Гипотеза не отвергается')
# Out:
# Независимый t-test: p-value = 1.8850394384715216e-31
# Гипотеза отвергается

# %% [markdown]
# **Проверка средних выручек**

# %%
print(f'''Средняя и медианная выручка для пользователей с подпиской:
    mean: {data_revenue_ultra.mean()}
    median: {data_revenue_ultra.median()}''')

print(f'''\nСредняя и медианная выручка для пользователей без подписки:
    mean: {data_revenue_free.mean()}
    median: {data_revenue_free.median()}''')
# Out:
# Средняя и медианная выручка для пользователей с подпиской:
#     mean: 362.7921906022502
#     median: 337.0
#
# Средняя и медианная выручка для пользователей без подписки:
#     mean: 328.6413651073845
#     median: 274.0

# %% [markdown]
# **Вывод**:
#
# Таким образом оба теста отвергают гипотезу о том, что средняя выручка от пользователей с подпиской не больше чем от людей без подписки. В целом, это видно по средним значениям выручки

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Здесь стоит еще раз проверить результат после корректировки таблицы с помесячной выручкой.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
#
# </div>

# %% [markdown]
# ### Гипотеза о количестве обращений
#
# Представьте такую ситуацию: техническая команда сервиса обновила сервера, с которыми взаимодействует мобильное приложение. Она надеется, что из-за этого количество обращений в техподдержку значимо снизилось. Некоторый файл содержит для каждого пользователя данные о количестве обращений до обновления и после него. Какой тест вам понадобился бы для проверки этой гипотезы?

# %% [markdown]
# Мы можем сформулировать две гипотезы:
#
# $H_0$: Количество обращений в тех. поддержку не изменилось
#
# $H_1$: Количество обращений в тех. поддержку снизилось
#
# Мы имеем дело с зависимыми выборками, и это нужно учитывать. По характеру данных можем иметь несколько решений:
#
# * Распределения имеют нормальный характер
#
# В этом случае используем `ttest_rel`
#
# * Распределения имеют не нормальный характер
#
# В этом случае используем `wilcoxon` ([тест Уилксона](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.wilcoxon.html)) - проверяет нулевую гипотезу о том, что две связанные парные выборки происходят из одного и того же распределения. В частности, он проверяет, является ли распределение разностей двух выборок симметричным относительно нуля. Это непараметрическая версия парного T-критерия.
#
# Так как гипотеза является односторонней, в обоих случаях мы должны указать параметры в верном порядке:
#
# `(data_before, data_after, alternative='greater')`

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Вопрос: какую гипотезу мы будем проверять - одностороннюю или двустороннюю и какие гипотезы мы можем сформулировать?
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 📝
# Верно, только параметр alternative должен быть less, ведь мы проверяем левостороннюю гипотезу "𝐻1: Количество обращений в тех. поддержку **снизилось**"
# </div>

# %% [markdown]
# ## Вывод

# %% [markdown]
# В ходе работы были изучены данные о работе популярного сервиса аренды самокатов GoFast.
#
# **Качество данных**
#
# Полученные данные не имели пропусков, были верно типизваны. Из правок было проведено только удаление полных дубликатов. Также ни по одному из категориальных признаков не было явного перекоса.
#
# Распределение дистанций поездок имеет два выраженных пика - на длинах $\approx 7$км и $\approx 1.5$км. Причем для подписчиков этораспределение смещено в большую сторону, относительно не подписчиков.
#
# Распределение длительностей имеет колоколообразное распределение. Для подписчиков и не подписчиков пики длительностей находятся примерно на одном уровне $\approx 15-20$ минут, причем группа людей без подписок имеет одиночный пик на длительности 0.5 мин. Это может быть некоторой особенностью детекции времени.
#
# Также по имеющимся данным была расчитана выручка для всех клиентов, исходя из их тарфиного плана и количестве использований сервиса. Эти распределения не имели куполообразной формы - пик был смещен влево. Однако, сравнивая распределения для подписчиков и людей без подписки, можно увидеть, что пик выручки от подписчиков ($\approx 350$) находится правее, чем у не подписчиков ($\approx 200$).
#
# **Изучение данных и проверка гипотез**
#
# На основе собранной таблицы с данными были проверены некоторые гипотезы:
#
# * **Время поездки для пользователей с разным типом подписки**
#
#  $H_0$: Обе группы тратят одинаковое время
#
#  $H_1$: Люди с подпиской тратят больше времени
#
# Длительности поездки имели распределение, отличное от номрального:
#
#     Тест Шапиро-Уилка для пользователей с подпиской: p-value = 3.0510050003555167e-21
#
#     Тест Шапиро-Уилка для пользователей без подписки: p-value = 2.665247016142569e-11
#
# Поэтому для проверки гипотез были использованы как параметрический t-test для независимых выборок, так и непараметрический u-test:
#
#     Независимый t-test: p-value = 1.2804098316645618e-34
#
#     U-test: p-value = 3.0317220611813157e-28
#
# По результатам обоих тестов мы отвергли нулевую гипотезу в пользву альтернативной.
#
# * **Дистанция поездки пользователей с подпиской**
#
#  $H_0$: Среднее расстояние пользователей с подпиской не больше 3130 м
#
#  $H_1$: Подписчики в среднем проезжают расстояние больше 3130 м
#
# Данные также были распределены не нормально:
#
#     Тест Шапиро-Уилка для пользователей с подпиской: p-value = 0.0
#
# Также имелся умеренный скос данных влево:
#
#     Показатель перекоса : -0.83
#
# Были проведены два теста - тест Уилкоксона и t-test для одной выборки:
#
#     Тест Уилкоксона: p-value = 0.0001690509558810868
#
#     T-test: p-value = 0.9195368847849785
#
# Таким образом, несмотря на то, что среднее меньше 3130 м, статистически, согласно t-тесту, мы не можем отвергать гипотезу о том, что средняя дистанция не больше порога. Однако тест Уилкоксона, проверяющий распределены ли значения симметрично около 0, отвергает эту гипотезу, в пользу того, что среднее значение все-таки больше.
#
# Так как данные не распределены по нормальному закону и имеют сильный перекос, в этой задаче стоит все-таки отвергнуть гипотезу о том, что среднее время подписчиков не больше оптимального.
#
#  * **Помесячная выручка от пользователей разных групп**
#
#  $H_0$: Средняя помесячная выручка от двух групп равна
#
#  $H_1$: Среднее выручка от пользователей с подпиской выше
#
# Данные о выручка распределены не нормально:
#
#     Тест Шапиро-Уилка для пользователей с подпиской: p-value = 0.0
#
#     Тест Шапиро-Уилка для пользователей без подписки: p-value = 0.0
#
# Присутствует сильный перекос вправо:
#
#     Показатель перекоса выручки от пользователей с подпиской: 1.548002095914749
#
#     Показатель перекоса выручки от пользователей без подписки: 1.3362457533067031
#
# Для таких условий были проведены два теста - непарамтерический тест Манна-Уитни и t-test для независимых выборок:
#
#     U-test: p-value = 1.3577968590692359e-132
#
#     Независимый t-test: p-value = 1.8850394384715216e-31
#
# Таким образом оба теста отвергают гипотезу о том, что средняя выручка от пользователей с подпиской не больше чем от людей без подписки. В целом, это видно по средним значениям выручки.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Для большей наглядности для заказчика предлагаю структурировать итоговые выводы, выделяя ключевые аспекты работы. В финальном разделе стоит максимально детализировать и обогатить информацией с конкретными цифрами все найденные закономерности и особенности в данных в ходе исследования.
#
# Давай сделаем обзорную часть более развернутой, чтобы подчеркнуть качество проведенной работы и предоставить заказчику полное понимание проведенного анализа.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
#
# </div>

# %% [markdown]
# ## Шаг 7. Распределения

# %% [markdown]
# ### Задача 1

# %% [markdown]
# Отделу маркетинга GoFast поставили задачу: нужно провести акцию с раздачей промокодов на один бесплатный месяц подписки, в рамках которой как минимум
# 100 существующих клиентов должны продлить эту подписку. То есть по завершении периода действия подписки пользователь может либо отказаться от неё, либо продлить, совершив соответствующий платёж.
#
# Эта акция уже проводилась ранее и по итогу выяснилось, что после бесплатного пробного периода подписку продлевают 10% пользователей. Выясните, какое минимальное количество промокодов нужно разослать, чтобы вероятность не выполнить план была примерно 5%. Подберите параметры распределения, описывающего эту ситуацию, постройте график распределения и сформулируйте ответ на вопрос о количестве промокодов.

# %% [markdown]
# Для решения этой задачи стоит воспользоваться биномиальным распределением
#
# Имеем:
#
# Требуемое количество успехов: $k=100$
#
# Вероятность успеха: $p=0.1$
#
# Допустимая вероятность неудачи $P(k < 100) = 5\%$

# %% [markdown]
# Будем подбирать значение n, чтобы в эксперименте выполнялось условие на вероятность неудачи

# %%
k = 100
p = 0.1

for n in range(100, 10000):
    
    distr = st.binom(n, p)

    if distr.cdf(k - 1) <= 0.05:
        print(f'Подходящее значение n = {n}')
        break
    elif n == 10000:
        print('Надо увеличить зону поиска')
# Out:
# Подходящее значение n = 1161

# %% [markdown]
# Мы нашли подходящий параметр. Теперь можно построить график распределения.

# %%
k_values = np.arange(distr.ppf(0.001), distr.ppf(0.999))

ax = sns.barplot(
    x=k_values,
    y=[distr.pmf(k) for k in k_values]
)

step = 10

ax.axvline(k / step, ls='--', label=f'k = {k}')
ax.xaxis.set_major_locator(MultipleLocator(step))

plt.title(f'Биномиальное распределение (n={n}, p={p})')
plt.xlabel('Число продлений')
plt.ylabel('Вероятность')
plt.legend();

# %% [markdown]
# **Вывод**:
#
# Для того, чтобы после прохождения акции мы имели 100 новых пользователей с подпиской с вероятностью более 5% нам необходимо раздать 1161 промокодов

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Отлично! Здорово, что выполнил необязательное задание.
# </div>

# %% [markdown]
# ### Задача 2

# %% [markdown]
# Отдел маркетинга рассылает клиентам push-уведомления в мобильном приложении. Клиенты могут открыть его или не открывать. Известно, что уведомления открывают около
# 40 % получивших клиентов. Отдел планирует разослать 1 млн уведомлений. С помощью аппроксимации постройте примерный график распределения и оцените вероятность того, что уведомление откроют не более 399,5 тыс. пользователей.

# %% [markdown]
# У нас есть биномиальное распределение:
#
# $n = 10^6$
#
# $p = 0.4$
#
# Для 1 млн уведомлений мы можем использовать нормальную аппроксимацию со следующими параметрами:
#
# $\mu = n \cdot p = 10^6 \cdot 0.4 = 400000$
#
# $\sigma = \sqrt{n \cdot p \cdot (1-p)} = \sqrt{10^6 \cdot 0.4 \cdot 0.6} = \sqrt{240000}$

# %% [markdown]
# Найдем вероятность того, что уведомление откроют не более 399.5 тыс. пользователей

# %%
n = 1e6
p = 0.4

mu = n * p
sigma = np.sqrt(n * p * (1 - p))

distr = st.norm(mu, sigma)

print(f'Искомая вероятность P = {distr.cdf(399500):.2%}')
# Out:
# Искомая вероятность P = 15.37%

# %% [markdown]
# Построим приблизительный график распределения

# %%
x = np.linspace(mu - 4 * sigma, mu + 4 * sigma, 1000)

y = distr.pdf(x)

sns.lineplot(
    x=x, 
    y=y
)

plt.axvline(399500, ls='--', label=f'k = 399500')

plt.title(f'Нормальная аппроксимация биномиального распределения \
(n={int(n)}, p={p})')

plt.xlabel('Число открытий')
plt.ylabel('Вероятность')
plt.legend();

# %% [markdown]
# **Вывод**:
#
# Для исследуемого распределения вероятность того, что уведомление откроют не более 399.5 тыс. пользователей равна $\approx 15.37\%$

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Совершенно верно.
# </div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.1</b>
#
# 👋
# Даниил, проект выполнен отлично. Особое внимание к деталям и структурированное оформление облегчает процесс просмотра и понимания материала. Все ключевые моменты в данных успешно выделены и четко обоснованы, при этом код написан эффективно. Есть несколько рекомендаций, и после внесения корректировок я готов принять проект.
#
# Удачи в доработках, жду!

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.2</b>
#
# 👋
#
# Даниил, спасибо тебе за исправления критических моментов, а также спасибо за хорошую работу.
#
# Поздравляю с успешным завершением проекта 🥳 🎉
#
# И желаю успехов в новых работах 😊
